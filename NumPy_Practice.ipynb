# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.6

# %%
import numpy as np
import numpy as np

arr = np.array([1, 2, 3])
print(arr)
# Out:
# [1 2 3]

# %%
import numpy as np

arr_2d = np.array([[1, 2, 3],
                   [4, 5, 6]])
print(arr_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

print(np.zeros((3,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np

print(np.ones((2,4)))
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
import numpy as np

print(np.eye(3))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import numpy as np

print(np.arange(0, 10, 2))
# Out:
# [0 2 4 6 8]

# %%
import numpy as np

print(np.linspace(0, 1, 5))
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
import numpy as np

print(np.random.rand(3,2))
# Out:
# [[0.92317042 0.77501321]
#  [0.42948235 0.42578484]
#  [0.01132761 0.2631998 ]]

# %%
import numpy as np

print(np.random.randn(3,2))
# Out:
# [[-1.6702543  -0.9092626 ]
#  [ 0.47070488  0.30392971]
#  [ 0.31607771  1.14364147]]

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
import numpy as np

a = np.array([1, 2, 3])

print(a + 5)
# Out:
# [6 7 8]

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

np.save("array.npy", arr)

loaded_arr = np.load("array.npy")

print(loaded_arr)
# Out:
# [1 2 3 4]

# %%
import pandas as pd

print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas as pd
#       2
#       3 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pandas'
